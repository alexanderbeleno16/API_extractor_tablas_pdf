# %%
from tabula import read_pdf 
from tabulate import tabulate 
import numpy as np
import pandas as pd 
from datetime import datetime
from googletrans import Translator

#------------------------- PARA LOS ESTADOS DE LA ENTIDAD {SUPER SOCIEDADES} --------------------------------


# PRUEBAS ESTADOS:
#Nota: Stream busca espacios en blanco entre columnas, mientras que Lattice busca líneas de límite entre columnas.area=(3.167899475097656, 2.52, 609.2278994750976, 1005.48)
# df = read_pdf("carpeta_pdf/documentos_ent_SS/estado intervenidas.PDF", pages="all", area=(3.167899475097656, 2.52, 609.2278994750976, 1005.48), stream=False, lattice=True, output_format="dataframe") 
# df = read_pdf("carpeta_pdf/ESTADO 102.pdf", pages="all", area=(164.43, 40.95, 584.01, 967.05), output_format="dataframe", stream=False, lattice=True) 
df = read_pdf("carpeta_pdf/documentos_prueba_autos_sr_juan/1658743688.6982_121-24.pdf", pages="all", area=(164.43, 40.95, 584.01, 967.05), output_format="dataframe", stream=False, lattice=True) 






#COLUMNAS:
columnas = df[0].columns.values.tolist()            # print(columnas)
formato="0"     #SIN FORMATO
for col in columnas:     
    col = str(col).replace("\n", " ").replace("\r", " ").replace("(", "").replace(")", "") 
    print( col )
    if col in ["DEPENDENCIA", "SOCIEDAD", "PARTES INTERESADAS", "TRÁMITE"]:     #FORMATO 1
        formato="1"
    elif col in ["No. PROCESO", "DECISIÓN"]:          #FORMATO 2
        formato="2"      


print( columnas ) 
# print( type(df[0]) ) 
# print( tabulate([df], tablefmt="pretty") )
# print( df[0] )
# Out:
# ESTADO No
# Unnamed: 1
# 121
# Unnamed: 3
# Unnamed: 4
# Unnamed: 5
# Unnamed: 6
# Fecha Estado: 25/07/2022
# Unnamed: 8
# Página:       1
# ['ESTADO No', 'Unnamed: 1', '121', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Fecha Estado: 25/07/2022', 'Unnamed: 8', 'Página:       1']

# %%
def isfloat(num):
    try:
        float(num)
        return True
    except ValueError:
        return False    
    
def isint(num):
    try:
        int(num)
        return True
    except ValueError:
        return False   

#Cambia el formato de la fecha a Y-m-d (la fecha llega en formato d/m/Y)
def convertidor_formato_fecha(fecha):
    date_sr_aux       = pd.to_datetime(pd.Series(fecha), infer_datetime_format=True) 
    change_format     = date_sr_aux.dt.strftime('%Y-%m-%d') 
    fecha_new_format  = change_format[0] 
    
    return fecha_new_format


def insertar_data(data):
    # cur = mysql.connection.cursor()
    contador=0
    coinciden=0
    no_coinciden=0
    for registros_aux in data:  
        contador=contador+1
        indice = 0

        # radicacion          = str(registros_aux[1]).replace("'",'').replace('"','').replace("´",'').replace('\\','').replace(',','').replace("\n", " ").replace("\r", " ");
        # clase_proceso       = str(registros_aux[2]).replace("'",'').replace('"','').replace("´",'').replace('\\','').replace(',','').replace("\n", " ").replace("\r", " ");
        # demandante          = str(registros_aux[3]).replace("'",'').replace('"','').replace("´",'').replace('\\','').replace(',','').replace("\n", " ").replace("\r", " ");
        # demandado           = str(registros_aux[4]).replace("'",'').replace('"','').replace("´",'').replace('\\','').replace(',','').replace("\n", " ").replace("\r", " ");
        # fecha_inicio        = str(registros_aux[5]).replace("'",'').replace('"','').replace("´",'').replace('\\','').replace(',','').replace("\n", " ").replace("\r", " ");
        # fecha_vencimiento   = str(registros_aux[6]).replace("'",'').replace('"','').replace("´",'').replace('\\','').replace(',','').replace("\n", " ").replace("\r", " ");
        # tipo_traslado       = str(registros_aux[7]).replace("'",'').replace('"','').replace("´",'').replace('\\','').replace(',','').replace("\n", " ").replace("\r", " ");
        # print(str(registros_aux[6]))
        # indice+=1
        expediente          = str(registros_aux[indice]).replace("'",'').replace('"','').replace("´",'').replace('\\','').replace(',','').replace("\n", " ").replace("\r", " ");indice+=1
        clase_proceso       = str(registros_aux[indice]).replace("'",'').replace('"','').replace("´",'').replace('\\','').replace(',','').replace("\n", " ").replace("\r", " ");indice+=1
        demandante          = str(registros_aux[indice]).replace("'",'').replace('"','').replace("´",'').replace('\\','').replace(',','').replace("\n", " ").replace("\r", " ");indice+=1
        demandado           = str(registros_aux[indice]).replace("'",'').replace('"','').replace("´",'').replace('\\','').replace(',','').replace("\n", " ").replace("\r", " ");indice+=1
        fecha_inicio        = str(registros_aux[indice]).replace("'",'').replace('"','').replace("´",'').replace('\\','').replace(',','').replace("\n", " ").replace("\r", " ");indice+=1
        fecha_vencimiento   = str(registros_aux[indice]).replace("'",'').replace('"','').replace("´",'').replace('\\','').replace(',','').replace("\n", " ").replace("\r", " ");indice+=1
        tipo_traslado       = str(registros_aux[indice]).replace("'",'').replace('"','').replace("´",'').replace('\\','').replace(',','').replace("\n", " ").replace("\r", " ");
        
        #Formato #1
        # fecha_inicio_aux      = convertidor_formato_fecha(fecha_inicio)
        # fecha_vencimiento_aux = convertidor_formato_fecha(fecha_vencimiento)
        # expediente_aux  = str(expediente[3:len(expediente)])   
        # if len(expediente_aux)<5:    
        #     expediente_aux = expediente_aux.zfill(5) 
        # expediente_anio = "20"+expediente[0:2]   
        
        
        #Formato #2
        expediente_aux  = str(expediente[5:len(expediente)])   
        if len(expediente_aux)<5:    
            expediente_aux = expediente_aux.zfill(5) 
        expediente_anio = expediente[0:4]   
        
        # print( "Original: " + expediente + " Año radicado: " + expediente_anio + " Radicado: " + expediente_aux)
        # print(tipo_traslado)
        # print(expediente, "\n", clase_proceso, "\n", demandante, "\n", demandado, "\n", fecha_inicio, "\n", fecha_vencimiento, "\n", tipo_traslado)
        
        
        # if (tablaRegistros=="lupa_texto_fijalista"):  
        proceso = ""                                                   
        # proceso = json_post["dep_imagen"]+json_post["mun_imagen"]+ json_post["ent_imagen"]+json_post["esp_imagen"]+json_post["desp_imagen"]+radicacion_anio+radicacion_aux
        proceso = "16" + "007" + "96" + "90" + "008" + expediente_anio + expediente_aux
                    
        query = "INSERT IGNORE INTO lupa_texto_fijalista_entidades ( "            
        # query += " fijacion_id, "
        query += " `texto_fijalista_proceso`, "
        query += " `texto_fijalista_departamento`, "
        query += " `texto_fijalista_municipio`, "
        query += " `texto_fijalista_entidad`, "
        query += " `texto_fijalista_especialidad`, "
        query += " `texto_fijalista_despacho`, "
        query += " `texto_fijalista_ano`, "
        query += " `texto_fijalista_radicacion`, "
        
        query += " `texto_fijalista_imagen`, "        
        query += " `texto_fijalista_fecha`, "
        query += " `texto_fijalista_fecha_fijalista`, "
        query += " `texto_fijalista_fecha_vencimiento`, "        
        query += " `texto_fijalista_demandante`, "
        query += " `texto_fijalista_demandado`, "
        query += " `texto_fijalista_motivo`, "
        query += " `texto_fijalista_fecha_grabacion`, "
        query += " `texto_fijalista_hora_grabacion`, "
        query += " `texto_fijalista_cod_operador` "            
        query += " ) VALUES ( "      
        # query += " '" + json_post['fijacion_id'] + "' "
        query += "  '" + proceso + "' "
        query += " , '" + "16" + "' "
        query += " , '" + "007" + "' "
        query += " , '" + "96" + "' "
        query += " , '" + "90" + "' "
        query += " , '" + "008" + "' "
        query += " , '" + expediente_anio + "' "
        query += " , '" + expediente_aux + "' "
        
        query += " , '" + "Ejemplo.png" + "' "
        query += " , CURDATE() "
        # query += " , '" + fecha_inicio_aux + "' "
        query += " , '" + fecha_inicio + "' "
        query += " , '" + fecha_vencimiento + "' "        
        query += " , '" + demandante + "' "
        query += " , '" + demandado + "' "        
        query += " , '" + tipo_traslado + "' "        
        query += " , CURDATE() "
        query += " , CURTIME() "
        query += " , '" + "1007173460" + "' "            
        query += ")"
        
        
        # print( expediente_aux, expediente_anio )
        # print( query )

        
        
        
        # print( "pdf: " + str(registros_aux[0]) + " | recorrido: " + str(contador) )
        # print( "pdf: " + str(registros_aux[0]) + " | recorrido: " + str(contador) )
        # if int(registros_aux[0]) == int(contador):            
        #     coinciden=coinciden+1            
        # else:
        #     no_coinciden=no_coinciden+1
            
        
        # cur.execute(query)
        # mysql.connection.commit()        
    # print( "coinciden: "+str(coinciden) )
    # print( "No coinciden: "+str(no_coinciden) )
        
    return query


def convertidor_string_date(cadena_fecha):  
    try:
        dia  = str(cadena_fecha).replace("\n", " ").replace("\r", " ").replace("(", "").replace(")", "").split()[1]
        mes  = str(cadena_fecha).replace("\n", " ").replace("\r", " ").replace("(", "").replace(")", "").split()[3]
        anio = str(cadena_fecha).replace("\n", " ").replace("\r", " ").replace("(", "").replace(")", "").split()[8]
        
        translator       = Translator(service_urls=['translate.googleapis.com'])
        mes_traducido    = translator.translate( mes, src='es', dest='en' )
        fecha_convertida = convertidor_formato_fecha( dia + mes_traducido.text[0:3] + anio ) #dd/month/yyyy: month es un texto. Ej: Mayo --> May (En ingles).
        
    except (ValueError, TypeError, IndexError) as e:
        print("Ocurrió un error en el formato #2 de Fijaciones en la columna de fecha: \nError:", e)
        exit() 
        
    return fecha_convertida
        
        


def armar_data(arr, formato):
    data=[]
    # print( arr )  
    for key in arr:  
        data.append(key)    
        
        # if formato=="1":   #FORMATO 1
        #     if isfloat(key[0]) and isint(key[0]):              
        #         data.append(key)    
        #         print( key )   
            
        # elif formato=="2":   #FORMATO 2
        #     if key[4]!="" and key[4]!=None and key[5]!="" and key[4]!=None:                 
        #         key[4] = convertidor_string_date(key[4])                      
        #         key[5] = convertidor_string_date(key[5])                      
        #         data.append(key) 
        #     else:
        #         print("Ocurrió un error en el formato #2 de Fijaciones, la columna de fecha esta vacia")
        #         exit()
             
    # print( "\n" , data )    
    return data



# df_arr = df[0].to_numpy().tolist()
df_arr  = df[0].to_numpy()
# print( df_arr )    

   
data  = armar_data(df_arr, formato)   
# if formato!="0":    #TIENE FORMATO
#     data  = armar_data(df_arr, formato)   
# else:
#     data = []            
# query = insertar_data(data)      

  

# print( data )    
print( tabulate(data, tablefmt="pretty") )
# Out:
# +------------------------------------------------------------------------------------------------------------------------------------------------------+------------------+-----------------------+------------------------+-----------------------------------------------------------------+------------+-------------+-----+-----+-----+
# |                                                                     No  Proceso                                                                      | Clase de Proceso |      Demandante       |       Demandado        |                      Descripción Actuación                      | Fecha Auto | Providencia | nan | nan | nan |
# |                                                               05001310501420090003200                                                                |    Ordinario     |  MONICA MARIA LOAIZA  |         I.S.S.         |                    Auto pone en conocimiento                    | 22/07/2022 |     PDF     | nan | nan | nan |
# |                                                                                                                                                      |                  |        CADAVID        |                        |   Ordena integrar al joven santiago gomez loaiza al encontrar   |            |             |     |     |     |
# |                                                                                                                                                      |                  |                       |                        |    que es mayor de edad. la notificación se realizara por la    |            |             |     |     |     |
# |                                                                                                                                                      |                  |                       |                        |                           secretaria.                           |            |             |     |     |     |
# |                                                               05001310501420140124500                                                                | Ejecutivo Conexo |    HERNAN DE JESUS    |      COLPENSIONES      |                  Auto que acepta desistimiento                  | 22/07/2022 |     PDF     | nan | nan | nan |
# |                                                                                                                                                      |                  |    ESCOBAR SALAZAR    |                        |     Del recurso de apelación presentado contra el auto que      |            |             |     |     |     |
# |                                                                                                                                                      |                  |                       |                        |            modificó la liquidación del crédito. LMC             |            |             |     |     |     |
# |                                                               05001310501420160019200                                                                |    Ordinario     |  JOSE JULIAN CORREA   |  INSTITUTO SOCIAL DE   |                 Sentencia de primera instancia                  | 22/07/2022 |     PDF     | nan | nan | nan |
# |                                                                                                                                                      |                  |         VELEZ         | VIVIENDA Y HABITAR DE  |      Se dicto fallo condenatorio y de forma solidaria. La       |            |             |     |     |     |
# |                                                                                                                                                      |                  |                       |        MEDELLIN        |   apoderada de  la  parte  actora,  del  isvimed,  y  de  los   |            |             |     |     |     |
# |                                                                                                                                                      |                  |                       |                        | llamados  en  garantía presentaron   recurso   el   cual   fue  |            |             |     |     |     |
# |                                                                                                                                                      |                  |                       |                        |    concedido   en   el   efecto suspensivo ante el superior.    |            |             |     |     |     |
# |                                                               05001310501420170000200                                                                |    Ejecutivo     |     PORVENIR S.A.     |    TOTAL  GROUP SAS    |                          Auto requiere                          | 22/07/2022 |     PDF     | nan | nan | nan |
# |                                                                                                                                                      |                  |                       |                        |      Requiere al apoderado de la parte ejecutante para que      |            |             |     |     |     |
# |                                                                                                                                                      |                  |                       |                        |      diligencie el formato de juramento que se anexa a la       |            |             |     |     |     |
# |                                                                                                                                                      |                  |                       |                        |                        providencia. LMC                         |            |             |     |     |     |
# |                                                               05001310501420170018000                                                                | Ejecutivo Conexo | UBIER DE JESUS OSPINA |  C.I CARMINALES  S.A   |                 Auto concede amparo de pobreza                  | 22/07/2022 |     PDF     | nan | nan | nan |
# |                                                                                                                                                      |                  |    GRANADA Y OTROS    |                        | Se   accede   a   la   acumulación   de   embargo   solicitada  |            |             |     |     |     |
# |                                                                                                                                                      |                  |                       |                        | por   el Juzgado  7°  Laboral,  y  se  accede  a  la  solicitud |            |             |     |     |     |
# |                                                                                                                                                      |                  |                       |                        |                  de  amparto  de pobreza. LMC                   |            |             |     |     |     |
# |                                                               05001310501420170080000                                                                | Ejecutivo Conexo |   ALCIDES DE JESÚS    |      COLPENSIONES      |                  Auto termina proceso por pago                  | 22/07/2022 |     PDF     | nan | nan | nan |
# |                                                                                                                                                      |                  |  BOLÍVAR SALDARRIAGA  |                        |       Ordena terminacion del proceso por pago total de la       |            |             |     |     |     |
# |                                                                                                                                                      |                  |                       |                        |        obligación, ordena   levantamiento   de   medidas        |            |             |     |     |     |
# |                                                                                                                                                      |                  |                       |                        |    cautelares   y   requiere   al apoderado judicial para la    |            |             |     |     |     |
# |                                                                                                                                                      |                  |                       |                        |                    entrega del titulo. eabm                     |            |             |     |     |     |
# |                                                               05001310501420180076600                                                                |  Disciplinario   |  JUZGADO 13 LABORAL   |   CARLOS JAVIER LARA   |                 Sentencia de primera instancia                  | 22/07/2022 |     PDF     | nan | nan | nan |
# |                                                                                                                                                      |                  |    DEL CIRCUITO DE    |        MONCADA         |        Absuelve  al  empleado  C.J.L.M.  de  los  cargos        |            |             |     |     |     |
# |                                                                                                                                                      |                  |       MEDELLIN        |                        |   disciplinarios formulados. Se declaro la prescrpcion de la    |            |             |     |     |     |
# |                                                                                                                                                      |                  |                       |                        |                      accion disciplinaria.                      |            |             |     |     |     |
# |                                                               05001310501420190057400                                                                |    Ordinario     | JAIME RAMIREZ LOZANO  |  COLPENSIONES E.I.C.E  |                       Auto corre traslado                       | 22/07/2022 |     PDF     | nan | nan | nan |
# |                                                                                                                                                      |                  |                       |                        |      De la demanda de reconvencion a la demandante  por el      |            |             |     |     |     |
# |                                                                                                                                                      |                  |                       |                        |  termino de 10 dias, para que se pronuncie si a bien lo tiene   |            |             |     |     |     |
# |                                                                                                                                                      |                  |                       |                        |  y se ordena notificar  a  la  Oficina  de  Bonos  Pensionales  |            |             |     |     |     |
# |                                                                                                                                                      |                  |                       |                        |  del  Ministerio  d Hacienda  en  calidad  de  Litis  Consorte  |            |             |     |     |     |
# |                                                                                                                                                      |                  |                       |                        |                   Necesario  por  pasiva- IGP                   |            |             |     |     |     |
# |                                                               05001310501420190062100                                                                | Ejecutivo Conexo |  OSCAR ABEL PALACIO   |  COLPENSIONES E.I.C.E  |                       Auto ordena oficiar                       | 22/07/2022 |     PDF     | nan | nan | nan |
# |                                                                                                                                                      |                  |                       |                        |   Ordena  oficiar  a  la  entidad  bancaria  conforme  a  lo    |            |             |     |     |     |
# |                                                                                                                                                      |                  |                       |                        |                         solictado. eabm                         |            |             |     |     |     |
# |                                                               05001310501420200013000                                                                | Ejecutivo Conexo |  JULIO ADAN GIRALDO   |      COLPENSIONES      |            Auto fija fecha audiencia y/o diligencia             | 22/07/2022 |     PDF     | nan | nan | nan |
# |                                                                                                                                                      |                  |                       |                        |  Fija fecha poar el 27 de enero de 2023 a las 8:30 data en la   |            |             |     |     |     |
# |                                                                                                                                                      |                  |                       |                        |        cual se  resolveran  las  excepciones  contra  el        |            |             |     |     |     |
# |                                                                                                                                                      |                  |                       |                        |     mandamiento  de  pago. proceso que se llevara de manera     |            |             |     |     |     |
# |                                                                                                                                                      |                  |                       |                        |               acumulada con otros procesos. eabm                |            |             |     |     |     |
# |                                                               05001310501420200034000                                                                | Ejecutivo Conexo |  BLANCA ORFA TORRES   |      COLPENSIONES      |                   Auto ordena correr traslado                   | 22/07/2022 |     PDF     | nan | nan | nan |
# |                                                                                                                                                      |                  |        BARRERA        |                        |  Ordena correr traslado a la parte ejecutada de la liquidacion  |            |             |     |     |     |
# |                                                                                                                                                      |                  |                       |                        |                        del credito. eabm                        |            |             |     |     |     |
# |                                                               05001310501420200042700                                                                |    Ordinario     |     ELENA CLAUDIA     |      COLPENSIONES      |                       Auto corre traslado                       | 22/07/2022 |     PDF     | nan | nan | nan |
# |                                                                                                                                                      |                  |    PATRICIA GOMEZ     |                        |  A  Skandia  para  que  se  pronuncie  de  la  demanda  si  a   |            |             |     |     |     |
# |                                                                                                                                                      |                  |       LIZARAZO        |                        |   bien  lo tiene.  Se  adjunta  Auto    link  del  expediente   |            |             |     |     |     |
# |                                                                                                                                                      |                  |                       |                        |           como  lo  habi solicitado dicha parte. IGP            |            |             |     |     |     |
# |                                                               05001310501420200043100                                                                | Ejecutivo Conexo |  LUZ INES CASTRILLON  |          UGPP          |                    Auto pone en conocimiento                    | 22/07/2022 |     PDF     | nan | nan | nan |
# |                                                                                                                                                      |                  |        PUERTA         |                        |     Pone en conocimiento de la parte actora resolución   y      |            |             |     |     |     |
# |                                                                                                                                                      |                  |                       |                        |       requiere para que realice pronunciamiento. concede        |            |             |     |     |     |
# |                                                                                                                                                      |                  |                       |                        |                          termino. eabm                          |            |             |     |     |     |
# |                                                               05001310501420210018800                                                                |    Ordinario     |    GERMAN DE JESUS    |       HEREDEROS        |                      Auto ordena emplazar                       | 22/07/2022 |     PDF     | nan | nan | nan |
# |                                                                                                                                                      |                  |        AGUDELO        |     DETERMINADOS E     |   Se  accede  a  la  solicitud  de  emplazamiento  y  nombra    |            |             |     |     |     |
# |                                                                                                                                                      |                  |                       |   INDETERMINADOS DE    |                          curador. LMC                           |            |             |     |     |     |
# |                                                                                                                                                      |                  |                       | EMILIO JIMENEZ LAVERDE |                                                                 |            |             |     |     |     |
# |                                                               05001310501420220012200                                                                | Ejecutivo Conexo |  MARIA TERESA GARCES  |     ADMINISTRADORA     |            Auto fija fecha audiencia y/o diligencia             | 22/07/2022 |     PDF     | nan | nan | nan |
# |                                                                                                                                                      |                  |        ARCILA         |     COLOMBIANA DE      |     Para que tengan lugar las audiencias de que tratan los      |            |             |     |     |     |
# |                                                                                                                                                      |                  |                       |       PENSIONES        |       artículos 372  y  373  del  CGP,  se  fija  el  día       |            |             |     |     |     |
# |                                                                                                                                                      |                  |                       |                        |            VEINTICUATRO  (24)  DE FEBRERO DE DOS MIL            |            |             |     |     |     |
# |                                                                                                                                                      |                  |                       |                        |          VEINTITRÉS (2023) A LAS OCHO Y TREINDA DE LA           |            |             |     |     |     |
# |                                                                                                                                                      |                  |                       |                        |                     MAÑANA (08:30 AM). LMC                      |            |             |     |     |     |
# |                                                                         nan                                                                          |       nan        |          nan          |          nan           |                               nan                               |    nan     |     nan     | nan | nan | nan |
# |                                                               05001310501420220024900                                                                |     Tutelas      |  ALEXANDER DE JESÚS   |   ESTABLECIMIENTO DE   |               Sentencia tutela primera instancia                | 22/07/2022 |     PDF     | nan | nan | nan |
# |                                                                                                                                                      |                  |    OSPINA PANIAGUA    |   SANIDAD MILITAR DE   |       TUTELA los  derechos fundamentales a la  salud,  en       |            |             |     |     |     |
# |                                                                                                                                                      |                  |                       |  MEDELLÍN - BATALLON   |   conexidad con la vida en condiciones dignas y la seguridad    |            |             |     |     |     |
# |                                                                                                                                                      |                  |                       |   ARTILLERIA  No. 4    |             social (Arts. 48 y 49 de la C.P.)  m.g.             |            |             |     |     |     |
# |                                                               05001310501420220025000                                                                |     Tutelas      |    MARINA PRECIADO    |         UARIV          |               Sentencia tutela primera instancia                | 22/07/2022 |     nan     | nan | nan | nan |
# |                                                                                                                                                      |                  |        POSADA         |                        |       DENIEGA por improcedente -hecho superado o carencia       |            |             |     |     |     |
# |                                                                                                                                                      |                  |                       |                        |    actual de objeto- el amparo de los derechos fundamentales    |            |             |     |     |     |
# |                                                                                                                                                      |                  |                       |                        |                         invocados. m.g.                         |            |             |     |     |     |
# |                                                               05001310501420220025200                                                                |     Tutelas      | MICHEL DAVID MIRANDA  |         UARIV          |               Sentencia tutela primera instancia                | 22/07/2022 |     PDF     | nan | nan | nan |
# |                                                                                                                                                      |                  |         LANCE         |                        |     Declara   hecho   superado.   Concede   término   para      |            |             |     |     |     |
# |                                                                                                                                                      |                  |                       |                        |                   impugar. Ordenar notificar                    |            |             |     |     |     |
# |                                                               05001310501420220026000                                                                |    Ejecutivo     |    HUMBERTO SIERRA    |  LUIS FERNANDO HORTA   |                Auto niega mandamiento ejecutivo                 | 22/07/2022 |     PDF     | nan | nan | nan |
# |                                                                                                                                                      |                  |         GAÑAN         |        LONDOÑO         |         Niega  mandamiento  de  pago  al  no  encontrar         |            |             |     |     |     |
# |                                                                                                                                                      |                  |                       |                        |   acreditados  los presupuestos del art. 100 del cptyss, 422    |            |             |     |     |     |
# |                                                                                                                                                      |                  |                       |                        |                             del cgp                             |            |             |     |     |     |
# |                                                               05001310501420220027100                                                                |     Tutelas      |   JOSE ALIRIO VERA    |     ADMINISTRADORA     |                       Auto admite tutela                        | 22/07/2022 |     PDF     | nan | nan | nan |
# |                                                                                                                                                      |                  |        OSORIO         |     COLOMBIANA DE      |          Ordena NOTIFICAR y reconoce personería.  m.g.          |            |             |     |     |     |
# |                                                                                                                                                      |                  |                       |       PENSIONES        |                                                                 |            |             |     |     |     |
# | DE CONFORMIDAD CON LO PREVISTO EN EL ART. 295 DEL CÓDIGO GENERAL DEL PROCESO Y PARA NOTIFICAR A LAS PARTES DE LAS ANTERIORES DECISIONES, EN LA FECHA |       nan        |          nan          |          nan           |                               nan                               |    nan     |     nan     | nan | nan | nan |
# |          25/07/2022 Y A LA HORA 8:00 A.M., SE FIJA EL PRESENTE ESTADO POR EL TÉRMINO LEGAL DE UN DIA SE DESFIJA EN LA MISMA A LAS 5:00 P.M.          |                  |                       |                        |                                                                 |            |             |     |     |     |
# |                                                            EVA ALEJANDRA BONILLA MURILLO                                                             |       nan        |          nan          |          nan           |                               nan                               |    nan     |     nan     | nan | nan | nan |
# |                                                                    SECRETARIO (A)                                                                    |                  |                       |                        |                                                                 |            |             |     |     |     |
# +------------------------------------------------------------------------------------------------------------------------------------------------------+------------------+-----------------------+------------------------+-----------------------------------------------------------------+------------+-------------+-----+-----+-----+
